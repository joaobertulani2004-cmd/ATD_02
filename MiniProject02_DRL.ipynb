# %% [markdown]
# ## IMPORTS

# %%
import os, sys, random, time
import warnings

import numpy as np
import torch
import tensorboard
import matplotlib.pyplot as plt

import gymnasium as gym
from stable_baselines3 import DQN, PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback

import imageio
from IPython.display import Image

# %% [markdown]
# ## STUP

# %%
# seeds
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
torch.cuda.manual_seed_all(SEED)

# Ensure deterministic behavior in CuDNN (NVIDIA backend for deep learning ops).
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("Python:", sys.version.split()[0])
print("PyTorch:", torch.__version__)
print("Device:", device)
print("CUDA:", torch.version.cuda if torch.cuda.is_available() else "None")
# Out:
# Python: 3.11.14
# PyTorch: 2.8.0
# Device: cpu
# CUDA: None

# %% [markdown]
# # Path

# %%
BASE_DIR = './project_results/'

# --- DQN Setup ---
DQN_DIR = os.path.join(BASE_DIR, 'DQN')
os.makedirs(DQN_DIR, exist_ok=True)
DQN_LOGS = os.path.join(DQN_DIR, "tensorboard")
DQN_MODEL = os.path.join(DQN_DIR, "model_dqn.zip")

# --- PPO Setup ---
PPO_DIR = os.path.join(BASE_DIR, 'PPO')
os.makedirs(PPO_DIR, exist_ok=True)
PPO_LOGS = os.path.join(PPO_DIR, "tensorboard")
PPO_MODEL = os.path.join(PPO_DIR, "model_ppo.zip")

print(f"Pastas criadas em: {os.path.abspath(BASE_DIR)}")
# Out:
# Pastas criadas em: c:\Users\tomfp\Documents\GitHub\ATD_02\project_results

# %% [markdown]
# ## ENVIRONMENT

# %%
def make_env():
    """Factory function that creates a fresh CartPole environment."""
    return gym.make("LunarLander-v3", render_mode="rgb_array")

env = DummyVecEnv([make_env])
# Out:
# <frozen importlib._bootstrap>:241: RuntimeWarning: Your system is avx2 capable but pygame was not built with support for it. The performance of some of your blits could be adversely affected. Consider enabling compile time detection with environment variables like PYGAME_DETECT_AVX2=1 if you are compiling without cross compilation.
# c:\Users\tomfp\anaconda3\envs\drl\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %% [markdown]
# ## MODEL

# %%
## MODEL DQN
model_dqn = DQN(
    policy='MlpPolicy',
    env=env,
    learning_rate=1e-3,
    buffer_size=50_000,
    exploration_fraction=0.2,
    batch_size=64,
    gamma=0.99,

    verbose=1,
    seed=SEED,
    tensorboard_log=DQN_LOGS, 
    device=device,            

    # Hiperparâmetros explícitos para o relatório
    train_freq=4, 
    learning_starts=500,  
    target_update_interval=10_000,
)
# Out:
# Using cpu device

# %%
## MODEL PPO
model_ppo = PPO(
    policy='MlpPolicy',
    env=env,
    learning_rate=3e-4,      # Padrão robusto para PPO
    n_steps=2048,            # Tamanho da janela de experiência antes do update
    batch_size=64,           # Tamanho do sub-batch para otimização
    n_epochs=10,             # Épocas de otimização por update
    gamma=0.99,              # Fator de desconto (mesmo do DQN para justiça)
    gae_lambda=0.95,         # Suavização de vantagem (exclusivo PPO/Actor-Critic)
    clip_range=0.2,          # Clipping do PPO (estabilidade teórica)
    ent_coef=0.01,           # Incentivo à exploração via entropia
    
    verbose=1,
    seed=SEED,               # Mesma seed inicial
    tensorboard_log=PPO_LOGS,
    device=device
)
# Out:
# Using cpu device

# %% [markdown]
# ## LOGGER

# %%
class DQNLoggingCallback(BaseCallback):
    """
    Custom callback for logging exploration-related metrics during training.

    This callback tracks:
    - The exploration rate (epsilon) over time
    - Episode rewards (one value per completed episode)
    - The number of gradient update steps performed by the agent

    The data collected here will later be used to plot training curves directly inside the notebook, complementing (but not replacing) TensorBoard.
    """
    def __init__(self, verbose=0):
        super().__init__(verbose)
        # list to store the metrics
        self.epsilon_history = []
        self.reward_history = []
        self.update_steps = []
        self.episode_reward = 0

    def _on_step(self) -> bool:
        # epsilon info
        if hasattr(self.model, "exploration_rate"):
            self.epsilon_history.append(self.model.exploration_rate)

        # reward info
        reward = self.locals.get("rewards")
        if reward is not None:
            self.episode_reward += reward[0]

        # check if episode has end (done)
        done = self.locals.get("dones")
        if done is not None and done[0]:
            self.reward_history.append(self.episode_reward)
            self.episode_reward = 0 # reset for next episode

        # number of gradient updates performed
        self.update_steps.append(self.model._n_updates)

        return True

# %% [markdown]
# ## Train

# %%
## --- Treino do DQN ---
print("Treino do DQN...")
callback_dqn = DQNLoggingCallback()

model_dqn.learn(
    total_timesteps=100_000,
    callback=callback_dqn,
    progress_bar=True,
    tb_log_name="run_1"
)
model_dqn.save(DQN_MODEL)
# Out:
# Treino do DQN...
# Logging to ./project_results/DQN\tensorboard\run_1_2
# c:\Users\tomfp\anaconda3\envs\drl\Lib\site-packages\rich\live.py:260: UserWarning: install "ipywidgets" for Jupyter
# support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 5793     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 382      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 3312     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 759      |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.06     |
# |    n_updates        | 64       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2583     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1122     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.33     |
# |    n_updates        | 155      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 2286     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1457     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.19     |
# |    n_updates        | 239      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 2155     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1809     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.02     |
# |    n_updates        | 327      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 2070     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2217     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.28     |
# |    n_updates        | 429      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 2031     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2560     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.27     |
# |    n_updates        | 514      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1987     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 2933     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.404    |
# |    n_updates        | 608      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1959     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3316     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.94     |
# |    n_updates        | 703      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1934     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3692     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.56     |
# |    n_updates        | 797      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.801    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1902     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4188     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.462    |
# |    n_updates        | 921      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.739    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1533     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5489     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.5      |
# |    n_updates        | 1247     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.716    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1534     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 5971     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.01     |
# |    n_updates        | 1367     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.693    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1538     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 6457     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.383    |
# |    n_updates        | 1489     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.666    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1539     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7036     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.52     |
# |    n_updates        | 1633     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.639    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1544     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7602     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.5      |
# |    n_updates        | 1775     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.595    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1511     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8536     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.791    |
# |    n_updates        | 2008     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.563    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1513     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9193     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.58     |
# |    n_updates        | 2173     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.536    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1513     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 9770     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.711    |
# |    n_updates        | 2317     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.502    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1512     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 10489    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.74     |
# |    n_updates        | 2497     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.468    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1510     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 11193    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.721    |
# |    n_updates        | 2673     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.425    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1496     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 12103    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.36     |
# |    n_updates        | 2900     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.374    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1470     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 13177    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.605    |
# |    n_updates        | 3169     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.281    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1310     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 15135    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.872    |
# |    n_updates        | 3658     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.213    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1279     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 16565    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.413    |
# |    n_updates        | 4016     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.112    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1168     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 18704    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.608    |
# |    n_updates        | 4550     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1103     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 20726    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.914    |
# |    n_updates        | 5056     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1040     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 23833    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.58     |
# |    n_updates        | 5833     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1014     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 25903    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.875    |
# |    n_updates        | 6350     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1010     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 28316    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.656    |
# |    n_updates        | 6953     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1011     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 29738    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.374    |
# |    n_updates        | 7309     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 977      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 32508    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.662    |
# |    n_updates        | 8001     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 960      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 34814    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.39     |
# |    n_updates        | 8578     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 958      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 36474    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.851    |
# |    n_updates        | 8993     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 963      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 38065    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.634    |
# |    n_updates        | 9391     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 962      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 39826    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2        |
# |    n_updates        | 9831     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 963      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 41465    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.9      |
# |    n_updates        | 10241    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 933      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 44368    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.598    |
# |    n_updates        | 10966    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 923      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 47142    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.76     |
# |    n_updates        | 11660    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 922      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 49023    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.24     |
# |    n_updates        | 12130    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 917      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 51492    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.535    |
# |    n_updates        | 12747    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 907      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 54033    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.838    |
# |    n_updates        | 13383    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 900      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 56657    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.572    |
# |    n_updates        | 14039    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 903      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 59253    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.685    |
# |    n_updates        | 14688    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 901      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 61324    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.396    |
# |    n_updates        | 15205    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 904      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 63204    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.484    |
# |    n_updates        | 15675    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 888      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 66402    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.336    |
# |    n_updates        | 16475    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 869      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 69857    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.456    |
# |    n_updates        | 17339    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 862      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 73286    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.581    |
# |    n_updates        | 18196    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 848      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 76710    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.07     |
# |    n_updates        | 19052    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 836      |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 80386    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.458    |
# |    n_updates        | 19971    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 822      |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 84386    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.196    |
# |    n_updates        | 20971    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 814      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 88072    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.448    |
# |    n_updates        | 21892    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 807      |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 92072    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.259    |
# |    n_updates        | 22892    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 804      |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 96072    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.317    |
# |    n_updates        | 23892    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 805      |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 99264    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.353    |
# |    n_updates        | 24690    |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
## --- Treino do PPO ---
print("\nTreino do PPO...")
callback_ppo = DQNLoggingCallback()

model_ppo.learn(
    total_timesteps=100_000,
    callback=callback_ppo,
    progress_bar=True,
    tb_log_name="run_1"
)
model_ppo.save(PPO_MODEL)
# Out:
# Treino do PPO...
# Logging to ./project_results/PPO\tensorboard\run_1_1
# -----------------------------
# | time/              |      |
# |    fps             | 2107 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1494         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0071839932 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000301     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.03e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00624     |
# |    value_loss           | 1.78e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1374         |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0066302596 |
# |    clip_fraction        | 0.0251       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00167      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 298          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00538     |
# |    value_loss           | 1.02e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1315        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006231291 |
# |    clip_fraction        | 0.0267      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.00399    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 244         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00745    |
# |    value_loss           | 1.16e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1271        |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009432223 |
# |    clip_fraction        | 0.0491      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.0927     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 397         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00825    |
# |    value_loss           | 763         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1253        |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011990761 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.003      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 214         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 495         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1243         |
# |    iterations           | 7            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0116827665 |
# |    clip_fraction        | 0.0783       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -0.0006      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 170          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0107      |
# |    value_loss           | 376          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1233         |
# |    iterations           | 8            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0046983864 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -0.0121      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 180          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0033      |
# |    value_loss           | 476          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1225         |
# |    iterations           | 9            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0075171986 |
# |    clip_fraction        | 0.122        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | -7.69e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 123          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0096      |
# |    value_loss           | 245          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1217        |
# |    iterations           | 10          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012805194 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -0.000358   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 132         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 276         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1206         |
# |    iterations           | 11           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0056981747 |
# |    clip_fraction        | 0.0416       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | -0.00107     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 193          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00684     |
# |    value_loss           | 438          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1175        |
# |    iterations           | 12          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.014188555 |
# |    clip_fraction        | 0.0826      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.000332    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 190         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00604    |
# |    value_loss           | 285         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1164         |
# |    iterations           | 13           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0069750655 |
# |    clip_fraction        | 0.0489       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.00593      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 85.2         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00991     |
# |    value_loss           | 243          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1157         |
# |    iterations           | 14           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0044723093 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | -3.23e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 180          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00217     |
# |    value_loss           | 391          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1120        |
# |    iterations           | 15          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010250634 |
# |    clip_fraction        | 0.0309      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | -0.0425     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 122         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00245    |
# |    value_loss           | 362         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1117         |
# |    iterations           | 16           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0046942895 |
# |    clip_fraction        | 0.0201       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.00344      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 103          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00494     |
# |    value_loss           | 364          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1086        |
# |    iterations           | 17          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009448896 |
# |    clip_fraction        | 0.0295      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | -0.0854     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 127         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00684    |
# |    value_loss           | 423         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1065         |
# |    iterations           | 18           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0049407473 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.0436       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 132          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00491     |
# |    value_loss           | 165          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1063         |
# |    iterations           | 19           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0048534325 |
# |    clip_fraction        | 0.0113       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.0414       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 60.4         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00499     |
# |    value_loss           | 185          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1060        |
# |    iterations           | 20          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005828684 |
# |    clip_fraction        | 0.0129      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | -0.0532     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 139         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00416    |
# |    value_loss           | 356         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1059        |
# |    iterations           | 21          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.007696636 |
# |    clip_fraction        | 0.0496      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.0447      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 157         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00653    |
# |    value_loss           | 271         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1043        |
# |    iterations           | 22          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.004162915 |
# |    clip_fraction        | 0.015       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.17        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 160         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00569    |
# |    value_loss           | 313         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1039         |
# |    iterations           | 23           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0047435313 |
# |    clip_fraction        | 0.0318       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.376        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52.9         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00424     |
# |    value_loss           | 162          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1022        |
# |    iterations           | 24          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004685685 |
# |    clip_fraction        | 0.0181      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.371       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 62.9        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00612    |
# |    value_loss           | 173         |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1004      |
# |    iterations           | 25        |
# |    time_elapsed         | 50        |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0126887 |
# |    clip_fraction        | 0.0468    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.14     |
# |    explained_variance   | 0.621     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 19.2      |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -0.00639  |
# |    value_loss           | 90.5      |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 994          |
# |    iterations           | 26           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0066522933 |
# |    clip_fraction        | 0.0413       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.561        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 78.7         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00447     |
# |    value_loss           | 110          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 980         |
# |    iterations           | 27          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.009836977 |
# |    clip_fraction        | 0.0522      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.064       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 159         |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.007      |
# |    value_loss           | 282         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 972         |
# |    iterations           | 28          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008594997 |
# |    clip_fraction        | 0.06        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.985      |
# |    explained_variance   | 0.575       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.9        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00667    |
# |    value_loss           | 85.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 966         |
# |    iterations           | 29          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.011144146 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.42        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.5        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00572    |
# |    value_loss           | 163         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 959          |
# |    iterations           | 30           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0038867653 |
# |    clip_fraction        | 0.0205       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.996       |
# |    explained_variance   | 0.577        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.4         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0026      |
# |    value_loss           | 123          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 938          |
# |    iterations           | 31           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0080421865 |
# |    clip_fraction        | 0.0854       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.981       |
# |    explained_variance   | 0.377        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 100          |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00798     |
# |    value_loss           | 174          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 932          |
# |    iterations           | 32           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0058368286 |
# |    clip_fraction        | 0.0623       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.94        |
# |    explained_variance   | 0.735        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.9         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00757     |
# |    value_loss           | 54.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 924         |
# |    iterations           | 33          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.007046208 |
# |    clip_fraction        | 0.036       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.988      |
# |    explained_variance   | 0.468       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.7        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00236    |
# |    value_loss           | 97.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 922         |
# |    iterations           | 34          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.012743161 |
# |    clip_fraction        | 0.0652      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.919      |
# |    explained_variance   | 0.695       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.93        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00637    |
# |    value_loss           | 91.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 907          |
# |    iterations           | 35           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0137287965 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.544        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.7         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00921     |
# |    value_loss           | 152          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 887         |
# |    iterations           | 36          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.009016678 |
# |    clip_fraction        | 0.0816      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.991      |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.1        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00815    |
# |    value_loss           | 100         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 871         |
# |    iterations           | 37          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.010989482 |
# |    clip_fraction        | 0.0839      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.992      |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.7        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 38.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 863         |
# |    iterations           | 38          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.003991223 |
# |    clip_fraction        | 0.0233      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.973      |
# |    explained_variance   | 0.842       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.1         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00144    |
# |    value_loss           | 18.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 39          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.007145081 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.2        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00825    |
# |    value_loss           | 38.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 856         |
# |    iterations           | 40          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012638593 |
# |    clip_fraction        | 0.0517      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 93.6        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00594    |
# |    value_loss           | 73.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 845         |
# |    iterations           | 41          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.008362077 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.804       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.83        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 15.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 843          |
# |    iterations           | 42           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0047520474 |
# |    clip_fraction        | 0.0716       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.852        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.18         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00547     |
# |    value_loss           | 13.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 834         |
# |    iterations           | 43          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.010419184 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.954      |
# |    explained_variance   | 0.746       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.9        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00883    |
# |    value_loss           | 47.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 829         |
# |    iterations           | 44          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008382224 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.72        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00664    |
# |    value_loss           | 15.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 823         |
# |    iterations           | 45          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.003884979 |
# |    clip_fraction        | 0.0133      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.925      |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.5        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00447    |
# |    value_loss           | 59.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 814          |
# |    iterations           | 46           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0068930155 |
# |    clip_fraction        | 0.0519       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.971       |
# |    explained_variance   | 0.796        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.04         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00314     |
# |    value_loss           | 14.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 811         |
# |    iterations           | 47          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.007441254 |
# |    clip_fraction        | 0.0704      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | 0.877       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.39        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00487    |
# |    value_loss           | 9.56        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 808          |
# |    iterations           | 48           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0041564386 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.928       |
# |    explained_variance   | 0.202        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.29         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00209     |
# |    value_loss           | 64           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 804          |
# |    iterations           | 49           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0046882564 |
# |    clip_fraction        | 0.0318       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.969       |
# |    explained_variance   | 0.721        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.01         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00463     |
# |    value_loss           | 46.3         |
# ------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
