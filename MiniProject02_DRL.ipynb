# %% [markdown]
# ### 1. Data Setup

# %%
# Import Libraries
# %pip install -q gymnasium[box2d] stable-baselines3[extra] moviepy

'''
This command will prepare the Python environment with:

The simulation environment (LunarLander),
The reinforcement learning algorithms (DQN and PPO),
And tools for visualization and video recording.
'''
# Out:
# Note: you may need to restart the kernel to use updated packages.
# '\nThis command will prepare the Python environment with:\n\nThe simulation environment (LunarLander),\nThe reinforcement learning algorithms (DQN and PPO),\nAnd tools for visualization and video recording.\n'

# %%
# Import Libraries
import os, sys, random, time
import warnings
import json

import numpy as np
import torch
import matplotlib.pyplot as plt

import gymnasium as gym
from stable_baselines3 import DQN, PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import BaseCallback

import imageio
from IPython.display import Image

# %%
# GPU or CPU init
USE_GPU = False   # True for GPU

# Device
if USE_GPU and torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
print("Selected device:", device)
print("CUDA version:", torch.version.cuda if torch.cuda.is_available() else "None")
# Out:
# CUDA available: True
# GPU: NVIDIA GeForce RTX 4060
# Selected device: cpu
# CUDA version: 12.1

# %%
# Reproducibility
SEEDS = [42, 62, 82]
TOTAL_TIMESTEPS = 100_000

def seed_setup(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    
    print("Device:", device)

    return device

# Creates an initialization function for the "LunarLander-v3" environment with a fixed seed
def make_env(seed: int):
    def _init():
        env = gym.make("LunarLander-v3")
        env.reset(seed=seed)
        return env
    return _init

# %%
# Outputs and data
BASE_DIR = "./project_results"

# DQN 
DQN_DIR = os.path.join(BASE_DIR, "DQN")
DQN_LOGS = os.path.join(DQN_DIR, "tensorboard")
os.makedirs(DQN_DIR, exist_ok=True)

# PPO 
PPO_DIR = os.path.join(BASE_DIR, "PPO")
PPO_LOGS = os.path.join(PPO_DIR, "tensorboard")
os.makedirs(PPO_DIR, exist_ok=True)

print(f"Results will be saved in: {os.path.abspath(BASE_DIR)}")
# Out:
# Results will be saved in: c:\Users\joaov\Desktop\PG\Code\ATD\ATD_02_DRL\ATD_02\project_results

# %% [markdown]
# ### 2. Models

# %%
class DQNLoggingCallback(BaseCallback):
    """
    Logs epsilon, episodic reward and number of updates during DQN training.
    """
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.epsilon_history = []
        self.reward_history = []
        self.update_steps = []
        self.episode_reward = 0.0

    def _on_step(self) -> bool:
        # Exploration rate (epsilon)
        if hasattr(self.model, "exploration_rate"):
            self.epsilon_history.append(self.model.exploration_rate)

        # Reward
        reward = self.locals.get("rewards")
        if reward is not None:
            self.episode_reward += reward[0]

        # End of episode
        done = self.locals.get("dones")
        if done is not None and done[0]:
            self.reward_history.append(self.episode_reward)
            self.episode_reward = 0.0

        # Gradient updates
        self.update_steps.append(self.model._n_updates)
        return True

# %%
class PPOLoggingCallback(BaseCallback):
    """
    Logs entropy, episodic reward, policy loss and value loss during PPO training.
    """
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.entropy_history = []
        self.policy_loss_history = []
        self.value_loss_history = []
        self.reward_history = []
        self.episode_reward = 0.0

    def _on_step(self) -> bool:
        # Reward
        reward = self.locals.get("rewards")
        if reward is not None:
            self.episode_reward += reward[0]

        # End of episode
        done = self.locals.get("dones")
        if done is not None and done[0]:
            self.reward_history.append(self.episode_reward)
            self.episode_reward = 0.0

        # Entropy
        entropy = self.locals.get("ent_coef")  # coef * entropy
        if entropy is not None:
            self.entropy_history.append(entropy)

        # Policy and value loss
        if "loss" in self.locals:
            loss = self.locals["loss"]
            # PPO returns a dict with keys: 'policy_loss', 'value_loss', 'entropy_loss' sometimes
            # We'll try to log if available
            if isinstance(loss, dict):
                self.policy_loss_history.append(loss.get("policy_loss", np.nan))
                self.value_loss_history.append(loss.get("value_loss", np.nan))

        return True

# %%
def evaluate_agent(model, env_fn, n_episodes=20, render=False):
    """
    Evaluates an agent over n_episodes deterministically.
    Returns episode rewards and lengths.
    """
    rewards = []
    lengths = []

    env = env_fn()
    for ep in range(n_episodes):
        obs, _ = env.reset()
        done = False
        total_reward = 0.0
        steps = 0

        while not done:
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, terminated, truncated, _ = env.step(action)
            total_reward += reward
            steps += 1
            done = terminated or truncated

            if render:
                env.render()

        rewards.append(total_reward)
        lengths.append(steps)

    env.close()
    return np.array(rewards), np.array(lengths)

# %% [markdown]
# ### 3. Training

# %%
dqn_eval_results = {}
ppo_eval_results = {}
dqn_training_curves = {}
ppo_training_curves = {}

for seed in SEEDS:
    print(f"SEED {seed} ")
    seed_setup(seed)

    # DQN
    print(f"\n>>> Starting DQN training with seed {seed} <<<\n")
    dqn_env = DummyVecEnv([make_env(seed)])
    dqn_callback = DQNLoggingCallback()

    model_dqn = DQN(
        policy="MlpPolicy",
        env=dqn_env,
        learning_rate=1e-3,
        buffer_size=50_000,
        exploration_fraction=0.2,
        batch_size=64,
        gamma=0.99,
        train_freq=4,
        learning_starts=500,
        target_update_interval=10_000,
        verbose=1,
        seed=seed,
        tensorboard_log=DQN_LOGS,
        device=device
    )

    model_dqn.learn(
        total_timesteps=TOTAL_TIMESTEPS,
        callback=dqn_callback,
        tb_log_name=f"dqn_seed_{seed}",
        progress_bar=True
    )

    # NOVO: salvar reward_history da seed
    dqn_training_curves[seed] = [float(r) for r in dqn_callback.reward_history]

    model_dqn.save(os.path.join(DQN_DIR, f"model_dqn_seed_{seed}"))
    dqn_env.close()

    # DQN Evaluation
    rewards, lengths = evaluate_agent(model_dqn, make_env(seed), n_episodes=20)
    dqn_eval_results[seed] = {
        "mean_reward": float(rewards.mean()),
        "std_reward": float(rewards.std()),
        "mean_length": float(lengths.mean()),
        "std_length": float(lengths.std())
    }
    print(f"DQN Seed {seed}: Mean Reward = {rewards.mean():.2f} ± {rewards.std():.2f}, "
          f"Mean Length = {lengths.mean():.1f} ± {lengths.std():.1f}")

    # PPO
    print(f"\n>>> Starting PPO training with seed {seed} <<<\n")
    ppo_env = DummyVecEnv([make_env(seed)])
    ppo_callback = PPOLoggingCallback()

    model_ppo = PPO(
        policy="MlpPolicy",
        env=ppo_env,
        learning_rate=3e-4,
        n_steps=2048,
        batch_size=64,
        n_epochs=10,
        gamma=0.99,
        gae_lambda=0.95,
        clip_range=0.2,
        ent_coef=0.01,
        verbose=1,
        seed=seed,
        tensorboard_log=PPO_LOGS,
        device=device
    )

    model_ppo.learn(
        total_timesteps=TOTAL_TIMESTEPS,
        tb_log_name=f"ppo_seed_{seed}",
        callback=ppo_callback,
        progress_bar=True
    )

    ppo_training_curves[seed] = [float(r) for r in ppo_callback.reward_history]

    model_ppo.save(os.path.join(PPO_DIR, f"model_ppo_seed_{seed}"))
    ppo_env.close()

    # PPO Evaluation
    rewards, lengths = evaluate_agent(model_ppo, make_env(seed), n_episodes=20)
    ppo_eval_results[seed] = {  
        "mean_reward": float(rewards.mean()),
        "std_reward": float(rewards.std()),
        "mean_length": float(lengths.mean()),
        "std_length": float(lengths.std())
    }
    print(f"PPO Seed {seed}: Mean Reward = {rewards.mean():.2f} ± {rewards.std():.2f}, "
          f"Mean Length = {lengths.mean():.1f} ± {lengths.std():.1f}")

print("Training finished for DQN and PPO with 3 independent seeds!")

# Save DQN results
with open(os.path.join(DQN_DIR, "eval_results.json"), "w") as f:
    json.dump(dqn_eval_results, f, indent=4)

# Save PPO results
with open(os.path.join(PPO_DIR, "eval_results.json"), "w") as f:
    json.dump(ppo_eval_results, f, indent=4)

with open(os.path.join(DQN_DIR, "training_curves.json"), "w") as f:
    json.dump(dqn_training_curves, f, indent=4)

with open(os.path.join(PPO_DIR, "training_curves.json"), "w") as f:
    json.dump(ppo_training_curves, f, indent=4)

print("Evaluation results and training curves saved to JSON")
# Out:
# SEED 42
# Device: cpu
#
# >>> Starting DQN training with seed 42 <<<
#
# Using cpu device
# c:\Users\joaov\miniconda3\envs\ATD_02\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# Logging to ./project_results\DQN\tensorboard\dqn_seed_42_1
# c:\Users\joaov\miniconda3\envs\ATD_02\Lib\site-packages\rich\live.py:260: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 12422    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 382      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 6245     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 759      |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.06     |
# |    n_updates        | 64       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 4571     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1122     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.33     |
# |    n_updates        | 155      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 4033     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1457     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.19     |
# |    n_updates        | 239      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 3788     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1809     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.02     |
# |    n_updates        | 327      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 3652     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2217     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.28     |
# |    n_updates        | 429      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 3548     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2560     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.27     |
# |    n_updates        | 514      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 3476     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2933     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.404    |
# |    n_updates        | 608      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 3429     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3316     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.94     |
# |    n_updates        | 703      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 3376     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3692     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.56     |
# |    n_updates        | 797      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.801    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 3305     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4188     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.462    |
# |    n_updates        | 921      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.739    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 3123     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5489     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.5      |
# |    n_updates        | 1247     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.716    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 3094     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5971     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.01     |
# |    n_updates        | 1367     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.693    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 3072     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6457     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.383    |
# |    n_updates        | 1489     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.666    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 3054     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7036     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.52     |
# |    n_updates        | 1633     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.639    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 3029     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7602     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.5      |
# |    n_updates        | 1775     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.595    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 2958     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 8536     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.791    |
# |    n_updates        | 2008     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.563    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 2918     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 9193     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.58     |
# |    n_updates        | 2173     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.536    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 2879     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 9770     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.711    |
# |    n_updates        | 2317     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.502    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 2853     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 10489    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.74     |
# |    n_updates        | 2497     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.468    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 2834     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 11193    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.721    |
# |    n_updates        | 2673     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.425    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 2792     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 12103    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.36     |
# |    n_updates        | 2900     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.374    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 2749     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 13177    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.605    |
# |    n_updates        | 3169     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.281    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 2697     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 15135    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.872    |
# |    n_updates        | 3658     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.19     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 2652     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 17051    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.91     |
# |    n_updates        | 4137     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 2576     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 20163    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.548    |
# |    n_updates        | 4915     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 2519     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 22596    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.474    |
# |    n_updates        | 5523     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 2479     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 24648    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.618    |
# |    n_updates        | 6036     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 2422     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 28180    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.18     |
# |    n_updates        | 6919     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 2403     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 29784    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.94     |
# |    n_updates        | 7320     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 2388     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 31548    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.636    |
# |    n_updates        | 7761     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 2371     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 33333    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.503    |
# |    n_updates        | 8208     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 2354     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 35730    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.562    |
# |    n_updates        | 8807     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 2336     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 38982    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.799    |
# |    n_updates        | 9620     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 2322     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 41568    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.393    |
# |    n_updates        | 10266    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 2314     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 43214    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.77     |
# |    n_updates        | 10678    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 2303     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 45332    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.648    |
# |    n_updates        | 11207    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 2296     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 47608    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.596    |
# |    n_updates        | 11776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 2288     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 49959    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.444    |
# |    n_updates        | 12364    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 2270     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 52358    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.77     |
# |    n_updates        | 12964    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 2264     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 54150    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.549    |
# |    n_updates        | 13412    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 2258     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 56913    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.5      |
# |    n_updates        | 14103    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 2244     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 59061    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.561    |
# |    n_updates        | 14640    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 2237     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 62258    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.887    |
# |    n_updates        | 15439    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 2232     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 64153    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.54     |
# |    n_updates        | 15913    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 2228     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 66769    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.656    |
# |    n_updates        | 16567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 2224     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 69149    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.565    |
# |    n_updates        | 17162    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 2220     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 72711    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.59     |
# |    n_updates        | 18052    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 2217     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 76711    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.18     |
# |    n_updates        | 19052    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 2213     |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 80711    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.573    |
# |    n_updates        | 20052    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 2211     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 83053    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.724    |
# |    n_updates        | 20638    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 2209     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 87053    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.336    |
# |    n_updates        | 21638    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 2207     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 91053    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.927    |
# |    n_updates        | 22638    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 2204     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 95053    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.492    |
# |    n_updates        | 23638    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 2203     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 99053    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.932    |
# |    n_updates        | 24638    |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# DQN Seed 42: Mean Reward = -76.50 ± 21.51, Mean Length = 1000.0 ± 0.0
#
# >>> Starting PPO training with seed 42 <<<
#
# Using cpu device
# Logging to ./project_results\PPO\tensorboard\ppo_seed_42_1
# -----------------------------
# | time/              |      |
# |    fps             | 2968 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2166         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0041115154 |
# |    clip_fraction        | 0.00718      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000313     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 561          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00464     |
# |    value_loss           | 1.66e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1981        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006672159 |
# |    clip_fraction        | 0.0115      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.0585     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 577         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00845    |
# |    value_loss           | 1.2e+03     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1903        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009944216 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.0422     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 505         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00834    |
# |    value_loss           | 999         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1857        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009556192 |
# |    clip_fraction        | 0.057       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.0253     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 375         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00851    |
# |    value_loss           | 776         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1830        |
# |    iterations           | 6           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007049645 |
# |    clip_fraction        | 0.0455      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.00527    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 498         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 1.15e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1806        |
# |    iterations           | 7           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010834806 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.00329    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 214         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00807    |
# |    value_loss           | 594         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1789         |
# |    iterations           | 8            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0029566288 |
# |    clip_fraction        | 0.00767      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -0.000322    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 203          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00341     |
# |    value_loss           | 637          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1776        |
# |    iterations           | 9           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005280279 |
# |    clip_fraction        | 0.0265      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 3.46e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 239         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00336    |
# |    value_loss           | 657         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1760         |
# |    iterations           | 10           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0056662047 |
# |    clip_fraction        | 0.0444       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -0.00525     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 285          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00679     |
# |    value_loss           | 660          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1750       |
# |    iterations           | 11         |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01276936 |
# |    clip_fraction        | 0.151      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.22      |
# |    explained_variance   | -0.00476   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 202        |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0102    |
# |    value_loss           | 599        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1747        |
# |    iterations           | 12          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010489276 |
# |    clip_fraction        | 0.055       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 3.7e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 305         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00384    |
# |    value_loss           | 695         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1736         |
# |    iterations           | 13           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0072114607 |
# |    clip_fraction        | 0.0515       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | -0.000551    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 529          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00317     |
# |    value_loss           | 711          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1730        |
# |    iterations           | 14          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.007959012 |
# |    clip_fraction        | 0.0813      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -2.13e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 159         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00684    |
# |    value_loss           | 284         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1728        |
# |    iterations           | 15          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010512657 |
# |    clip_fraction        | 0.0677      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.00182     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 125         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00541    |
# |    value_loss           | 384         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1727        |
# |    iterations           | 16          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010247767 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -0.00139    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 410         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00988    |
# |    value_loss           | 657         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1725        |
# |    iterations           | 17          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005304006 |
# |    clip_fraction        | 0.0419      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | -3.56e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 181         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00744    |
# |    value_loss           | 409         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1723        |
# |    iterations           | 18          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.002351317 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | -1.49e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 139         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00176    |
# |    value_loss           | 355         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1722          |
# |    iterations           | 19            |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00056105433 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.28         |
# |    explained_variance   | 0.000131      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 116           |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.00128      |
# |    value_loss           | 288           |
# -------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1721       |
# |    iterations           | 20         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.01059975 |
# |    clip_fraction        | 0.0564     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | -3.4e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 234        |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.00768   |
# |    value_loss           | 291        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1718       |
# |    iterations           | 21         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.00483613 |
# |    clip_fraction        | 0.0279     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.000156   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 131        |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00398   |
# |    value_loss           | 329        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1716        |
# |    iterations           | 22          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009600734 |
# |    clip_fraction        | 0.0372      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.00043     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.4        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00647    |
# |    value_loss           | 228         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1716        |
# |    iterations           | 23          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.011097187 |
# |    clip_fraction        | 0.0612      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.0604      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 92.8        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00536    |
# |    value_loss           | 146         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1715         |
# |    iterations           | 24           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0043283436 |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.147        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 59.1         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00469     |
# |    value_loss           | 197          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1713        |
# |    iterations           | 25          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.004867905 |
# |    clip_fraction        | 0.0631      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | -0.00482    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 117         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00753    |
# |    value_loss           | 256         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1713        |
# |    iterations           | 26          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.008760313 |
# |    clip_fraction        | 0.0702      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 131         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00605    |
# |    value_loss           | 213         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1712       |
# |    iterations           | 27         |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.00855236 |
# |    clip_fraction        | 0.0368     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.1       |
# |    explained_variance   | -0.15      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 98.2       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.00824   |
# |    value_loss           | 252        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1711        |
# |    iterations           | 28          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009029983 |
# |    clip_fraction        | 0.0761      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.325       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.2        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 130         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1709        |
# |    iterations           | 29          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.010597728 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.65        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.3        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00618    |
# |    value_loss           | 78.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1708        |
# |    iterations           | 30          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.008031111 |
# |    clip_fraction        | 0.0573      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.272       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.8        |
# |    n_updates            | 290         |
# ...
# |    clip_fraction        | 0.0865       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.239        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.3         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00653     |
# |    value_loss           | 199          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1702        |
# |    iterations           | 30          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.008028242 |
# |    clip_fraction        | 0.0486      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.42        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 88.7        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00768    |
# |    value_loss           | 67.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1702        |
# |    iterations           | 31          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.009759561 |
# |    clip_fraction        | 0.0978      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.123       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 78.3        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00811    |
# |    value_loss           | 170         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1701        |
# |    iterations           | 32          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.005859103 |
# |    clip_fraction        | 0.0507      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.955      |
# |    explained_variance   | 0.456       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.8        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00609    |
# |    value_loss           | 60.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1701        |
# |    iterations           | 33          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.014546569 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.135       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 70.2        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00572    |
# |    value_loss           | 99.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1699        |
# |    iterations           | 34          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.011863631 |
# |    clip_fraction        | 0.0932      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.973      |
# |    explained_variance   | 0.407       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.8        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00725    |
# |    value_loss           | 75.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1699         |
# |    iterations           | 35           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0063291825 |
# |    clip_fraction        | 0.0662       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.948       |
# |    explained_variance   | 0.13         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 90.2         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00609     |
# |    value_loss           | 111          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1699        |
# |    iterations           | 36          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.005420297 |
# |    clip_fraction        | 0.0311      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.0612      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.8        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00657    |
# |    value_loss           | 114         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1699         |
# |    iterations           | 37           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0052511967 |
# |    clip_fraction        | 0.0691       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.975       |
# |    explained_variance   | 0.503        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.5         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00611     |
# |    value_loss           | 30.1         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1698       |
# |    iterations           | 38         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.00445088 |
# |    clip_fraction        | 0.0266     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.933     |
# |    explained_variance   | 0.255      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 42.1       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.00502   |
# |    value_loss           | 117        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1698        |
# |    iterations           | 39          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.008928329 |
# |    clip_fraction        | 0.0707      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.873      |
# |    explained_variance   | 0.573       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.91        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00723    |
# |    value_loss           | 25.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1698         |
# |    iterations           | 40           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0063609267 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.863       |
# |    explained_variance   | 0.499        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.9         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00402     |
# |    value_loss           | 58.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1697        |
# |    iterations           | 41          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.008717538 |
# |    clip_fraction        | 0.0741      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.979      |
# |    explained_variance   | 0.658       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.6        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00767    |
# |    value_loss           | 21.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1697        |
# |    iterations           | 42          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.007979838 |
# |    clip_fraction        | 0.0515      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.389       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.82        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00356    |
# |    value_loss           | 50.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1697         |
# |    iterations           | 43           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0089290785 |
# |    clip_fraction        | 0.0725       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.909       |
# |    explained_variance   | 0.352        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 86           |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00525     |
# |    value_loss           | 79.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1697        |
# |    iterations           | 44          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.009000763 |
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.947      |
# |    explained_variance   | 0.852       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.12        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0076     |
# |    value_loss           | 8.65        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1692         |
# |    iterations           | 45           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0073507805 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.915       |
# |    explained_variance   | 0.806        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.26         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00542     |
# |    value_loss           | 8.62         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1681        |
# |    iterations           | 46          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009229155 |
# |    clip_fraction        | 0.0537      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.907      |
# |    explained_variance   | 0.314       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 158         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00432    |
# |    value_loss           | 111         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1681        |
# |    iterations           | 47          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.006606547 |
# |    clip_fraction        | 0.0556      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.949      |
# |    explained_variance   | 0.778       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.03        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0048     |
# |    value_loss           | 12.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1681         |
# |    iterations           | 48           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0057392446 |
# |    clip_fraction        | 0.0729       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.88         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00332     |
# |    value_loss           | 5.32         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1680         |
# |    iterations           | 49           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0032796736 |
# |    clip_fraction        | 0.00776      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.97        |
# |    explained_variance   | 0.204        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 100          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00267     |
# |    value_loss           | 173          |
# ------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# PPO Seed 82: Mean Reward = 27.55 ± 123.06, Mean Length = 737.2 ± 147.2
# Training finished for DQN and PPO with 3 independent seeds!
# Evaluation results and training curves saved to JSON

# %% [markdown]
# ### 4. Evaluetion

# %%
def plot_seeds(path, title, window=10):
    """
    Plots each seed with smoothing for better visualization.
    """
    with open(path, "r") as f:
        data = json.load(f)

    plt.figure(figsize=(16,6))

    colors = ["blue", "orange", "green"]

    for i, (seed, curve) in enumerate(data.items()):
        curve_smooth = np.convolve(curve, np.ones(window)/window, mode='valid')
        plt.plot(range(len(curve_smooth)), curve_smooth,
                 label=f"Seed {seed}",
                 color=colors[i % len(colors)],
                 alpha=0.8,
                 linewidth=2)

    plt.title(title, fontsize=16)
    plt.xlabel("Episode", fontsize=14)
    plt.ylabel("Reward", fontsize=14)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
plot_seeds(os.path.join(DQN_DIR, "training_curves.json"), "DQN - Reward por Seed")
plot_seeds(os.path.join(PPO_DIR, "training_curves.json"), "PPO - Reward por Seed")
